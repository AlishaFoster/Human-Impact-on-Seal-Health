# %% [markdown]
# # COGS 108 - An Analysis of Human Impact on Seal Health in Alaska
# # Final Video
# The final video can be found at the following link: https://youtu.be/LJArodtKiNA
#
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [X] YES - make available
# * [  ] NO - keep private
#
# # Names
#
# - Gino Angelici
# - Alisha Foster
# - Ben Garofalo
# - Matthew Pham
#
# # Abstract
#
# Amongst the many joys of San Diego, UC San Diego resides by the ocean-side, and is host to one of the most prolific Marine Biology institutions in the world. With the ever-surrounding presence of the sea, one of the most prominent peculiarities and attractions of La Jolla happen to be the Seals and the Sea Lions, which populate the La Jolla Coves and the Children's Pool. When looking over the general population of Sea Lions and their prevalence, our initial thoughts, were to examine and observe the relationship between Seal/Sea Lion population, and the traction of tourism and vacationing within the San Diego area, and specifically, La Jolla.
#
# However, given the lack of concrete data-sets relating to Seals and Sea-Lions in the greater San Diego area, our focus soon turned to a larger population and area: the Alaskan coastline, where a large density of Sea Lions reside. Thus, we realigned our interests towards the Alaskan Sea Lions, and tracking a relationship between Fishing and its effects on the local Sea Lion populations. To do that, we utilized three separate datasets: one for sea lion population, one for tracking the health of these very sea lions (Morphometrics), and one tracing the Ocean Economy across several different factors (establishments, RealGDP, etc.).
#
# We found that the Seals happen to be most prominently affected by the amount of construction that occurs within these marine spaces, which is strong related with the overall seal population, and the amount of seals killed over time. What most affects seal health happens to be the amount of offshore mineral extraction, and for the future predictors, we mainly must look towards Marine transportation as well as our general conservation efforts (Living resources), if we want these beautiful creatures to continue thriving.

# %% [markdown]
# # Research Question

# %% [markdown]
# What is the relationship between human intervention (tourism, mineral extraction, fishing, construction) and seal population in Alaska?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# ### Introduction
#
# One of the most important animals to the Arctic ecosystem is the ice seal. These cute, chubby mammals come in many species, such as bearded, ringed, spotted, and ribbon seals. Unfortunately for these rotund aquatic animals, there has been an unusual decline in seal health over the past decade from 2011-2018.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) Disease, climate change, and harmful human intervention have all impacted the serene icy landscape of the Arctic Circle, specifically in Alaska. Within the shrinking ice flats of the north, a delicate food web takes place that allows its wildlife to survive. Seals are known to occupy underwater lairs and hunt for fish and other invertebrates at the edge of these ice lands. Their hunting season also lines up with many Alaskan oil and gas activities such as ice road construction and seismic/drilling operations.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) These disturbances to the seals' habit threaten their health and safety. Without seals, the entire balance of the Arctic ecosystem could be destroyed in the future.
#
# ### Prior Work
#
# Many research projects have explored these impacts to seal health. One project conducted by the Alaska Department of Fish and Game surveyed ringed seal locations in the Beaufort Sea to see if their population was impacted by drilling operations in the area.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) Reasons for this study largely revolved around finding the best times and locations to carry out drilling and seismic construction while disturbing the least amount of seals possible. They found 60 breathing holes and 10 lairs under the ice, with the closest structures being within 19.5m of facilities and within an active ice road.Overall, this project revealed the close proximity of seal habitats to human construction and development, showing how their livelihood has become threatened in recent years.
#
# Another research study conducted in Alaska considers declining seal body fat and how that may be attributed to global warming and receding ice near the Bering Sea.<a name="cite_note-2"></a>[<sup>2</sup>](#cite_ref-2) While the study, which considered population and weather data from 2007-18, does not directly connect seal wellbeing to human overfishing, evidence suggested that decreasing seal health is connected to worsening diets in the Alaska region. Further exploration into the fishing of the region could reveal how fish population interacts with seal body weight. "The mothers, maybe, were not finding as much food in the period prior to the birth of their pups, when they were pregnant," author Boveng said.
#
# One last study touches on specific aspects of seal health, such as disease and body chemistry.<a name="cite_note-3"></a>[<sup>3</sup>](#cite_ref-3) Sea ice has been receding in recent years due to a multitude of factors such as climate change, ice drilling, and road construction. This has caused different types of seals to begin living in close proximity to each other. By taking a small sample of bearded, ringed, spotted, and ribbon seals from all across the Alaskan coast, researchers were able to test for diseases such as Brucella, Leptospira, avian influenza, herpesvirus PhHV-1, and morbillivirus. This paper summarizes that since ice seals have typically had low exposure to disease, their increased exposure to other seal populations has thus increased their mortality rate.
#
#
# ### References
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Quakenbush, L. T., A. Bryan, J. Crawford. 2023. Winter Ringed Seal Density within Beaufort Sea Oil and Gas Project Areas, Annual Report to Bureau of Ocean Energy Management, AK-21-01, Award No. M21AC00024, https://www.adfg.alaska.gov/static/research/programs/marinemammals/pdfs/icesealboem_m21ac00024_annual_report_2023.pdf.
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Peter L. Boveng, Heather L. Ziel, Brett T. McClintock, Michael F. Cameron, Body condition of phocid seals during a period of rapid environmental change in the Bering Sea and Aleutian Islands, Alaska, Deep Sea Research Part II: Topical Studies in Oceanography, Volumes 181–182, 2020, 104904, ISSN 0967-0645, https://doi.org/10.1016/j.dsr2.2020.104904.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Goertz CEC, Reichmuth C, Thometz NM, Ziel H and Boveng P (2019) Comparative Health Assessments of Alaskan Ice Seals. Front. Vet. Sci. 6:4.https://www.frontiersin.org/articles/10.3389/fvets.2019.00004/full

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Our hypothesis is that seal population will be negatively affected by fishing activity in Alaska, in theory because of bycatches (seals getting trapped in fishing equipment, etc) as well as in a reduction of viable food sources, and insignificantly affected by drilling and tourism activities. We do not expect to see correlation between seal population and increased drilling operations or tourism trends in the area because these activities more indirectly impact seal livelihood in non-fatal ways.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# - Dataset #1
#   - Dataset Name: Northern fur seal pup production, adult male counts and harvest data for the Pribilof Islands, Alaska 1909 to Present
#   - Link to the dataset: https://catalog.data.gov/dataset/northern-fur-seal-pup-production-adult-male-counts-and-harvest-data-for-the-pribilof-islands-al1
#   - Number of observations: 110
#   - Number of variables: 23
# - Dataset #2
#   - Dataset Name: Alaska Phocid Morphometrics
#   - Link to the dataset: https://catalog.data.gov/dataset/alaska-phocid-morphometrics2
#   - Number of observations: 1752
#   - Number of variables: 18
# - Dataset #3
#   - Dataset Name: Time-Series Data on the Ocean and Great Lakes Economy for Counties, States, and the Nation between 2005 and 2019 (Sector Level). For future reference, we will call this dataset 'Ocean Economy Dataset'.
#   - Link to the dataset: https://catalog.data.gov/dataset/time-series-data-on-the-ocean-and-great-lakes-economy-for-counties-states-and-the-nation-betwee3
#   - Number of observations: 53499
#   - Number of variables: 12
#
#
# The northern fur seal pup production, adult male counts and harvest data for the Pribilof Islands has 110 observations, one for each year between 1909 and 2018. The column acronym explanations can be found at this link: https://www.fisheries.noaa.gov/inport/item/28692. All of the numeric columns are integers. This includes year, haremp, idlep, haremg, idleg, mkillp, mkillg, fkillp, fillg, omkillp, omkillg, pbornp, pdeadp, pdeadg, ofkillp, ofkillg, stock, sep, and seg. The other columns methodp, methodg, and comment are represented using strings. Variables ending in p represent data from St. Paul and g represent data from St. George Island. Since the data is split by these islands, we could conduct t-tests to test the difference in declining seal population between the islands. Every column has missing data, so we would have to decide which columns have the least missing and keep those. Some of the more interesting variables are haremp and haremg which represent the counts of territorial males with females on St. Paul Island and St. George island during July. Pbornp, pborng, pkillp and pkillg represent pups born and killed on the islands. This could be used to determine seal health or also population rates. Most of the other csvs we are working with start from 2005, so we will probably drop the years from before 2005 when comparing data between the csvs and eventually merge them. We can also drop the comments and method columns as most are missing and do not provide useful information. Finally, we drop columns that have 80% or more nan values.
#
# The Alaskan Phocid Morphometrics dataset contains 17 morphometric parameters for a list of 1700 harbor, bearded, ringed, spotted and ribbon seals collected on research expeditions between 1991 and 2015. The data collection was done in discrete events, and is non-continuous (data was collected in 1991, but not for several years afterwards until 2004). The dataset contains useful phocid health parameters such as mass, length, girth, blubber thickness and blubber depth that can be used to determine overall health. These parameters are represented as 64 bit floating points. Additional comments and the phocid IDs are represented as string objects. For data wrangling, many of the rows and parameters are mostly unavailable (NaN), so they can be dropped from the dataset. It would also be useful to constrain the phocid health data to match the years in which data was collected for the other two datasets (2005 and onward) so that predictions and correlations can be reasonably drawn. This could also lead to combining the datasets under a common denominator of time, which could illuminate any relationships between the data over the years.
#
# The Ocean Economy Dataset describes six economic sectors that depend on the oceans and Great Lakes (Marine Construction, Living Resources [which includes fishing], Offshore Mineral Extraction, Ship and Boat Building, Tourism and Recreation, and Marine Transportation) plus a summary of All Ocean Sectors, and it measures four economic indicators: Establishments, Employment, Wages, and Gross Domestic Product (GDP). We will use these economic indicators to indicate the success and scale of the Sectors, which are our conceptualizations of human intervention. The dataset includes observations spanning from 2005 to 2021 across the nation on the levels of: regional, state, and county. We are only interested in the data involving Alaska on a state-wide level, so we will trim the dataset accordingly. We will tidy the data by dropping null rows and extraneous columns that are irrelevant to our research.

# %% [markdown]
# ## Northern fur seal pup production, adult male counts and harvest data for the Pribilof Islands, Alaska 1909 to Present

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# try reccomended dataset
# Cite dataset as: Alaska Ecosystems Program. 2019. Northern fur seal pup production, adult male counts and harvest data for the Pribilof Islands, Alaska 1909 to Present. NOAA Fisheries Open Data Portal: https://noaa-fisheries-afsc.data.socrata.com/Ecosystem-Science/Northern-fur-seal-pup-production-adult-male-counts/c983-ijgd
# here is explanation of the column labels https://www.fisheries.noaa.gov/inport/item/28692
# collected on st. george island and st. paul island (Pribilof Islands, Alaska), considers both harvesting for commercial and subsistence
# good background on northern fur seals: https://www.adfg.alaska.gov/static/education/wns/northern_fur_seal.pdf
seal1 = pd.read_csv('data/seal_data.csv')

# %%
plt.plot(seal1['year'], seal1['haremp'])
plt.xlabel('Year')
plt.ylabel('Counts of territorial males with females on St. Paul Island during July.')
# Out:
# Text(0, 0.5, 'Counts of territorial males with females on St. Paul Island during July.')

# %%
plt.plot(seal1['year'], seal1['idlep'])
plt.xlabel('Year')
plt.ylabel('Counts of territorial males with females on St. Paul Island during July.')
# Out:
# Text(0, 0.5, 'Counts of territorial males with females on St. Paul Island during July.')

# %%
# most of the other csvs go from 2005-
# filter based on that
seal1_2005 = seal1[seal1['year'] >= 2005]

# %%
# remove unhelpful columns
seal1_2005 = seal1_2005.drop(columns=['methodg', 'methodp', 'comment'])
seal1_2005.head()
# Out:
#      year  haremp   idlep  haremg  idleg  mkillp  mkillg  fkillp  fkillg  \
# 96   2005  3515.0  5811.0   905.0  634.0   479.0   139.0     NaN     NaN
# 97   2006  3669.0  6283.0   720.0  650.0   392.0   212.0     4.0     NaN
# 98   2007  3568.0  5270.0   744.0  559.0   269.0   208.0     3.0     2.0
# 99   2008  4119.0  5050.0   805.0  638.0   329.0   170.0     3.0     NaN
# 100  2009  4121.0  5226.0   873.0  824.0   341.0   113.0     NaN     1.0
#
#      omkillp  omkillg    pbornp   pborng  pdeadp  pdeadg  ofkillp  ofkillg  \
# 96       NaN      NaN       NaN      NaN     NaN     NaN      NaN      NaN
# 97       NaN      NaN  109961.0  17072.0  4994.0   712.0      NaN      NaN
# 98       NaN      NaN       NaN      NaN     NaN     NaN      NaN      NaN
# 99       NaN      NaN  102674.0  18160.0  5503.0   985.0      NaN      NaN
# 100      NaN      NaN       NaN      NaN     NaN     NaN      NaN      NaN
#
#      stock     sep    seg
# 96     NaN     NaN    NaN
# ...

# %%
# drop columns with more than 80 percent nan
seal1_2005 = seal1_2005.loc[:, seal1_2005.isnull().mean() < .8]

# %%
seal1_2005
# Out:
#      year  haremp   idlep  haremg   idleg  mkillp  mkillg  fkillp  fkillg  \
# 96   2005  3515.0  5811.0   905.0   634.0   479.0   139.0     NaN     NaN
# 97   2006  3669.0  6283.0   720.0   650.0   392.0   212.0     4.0     NaN
# 98   2007  3568.0  5270.0   744.0   559.0   269.0   208.0     3.0     2.0
# 99   2008  4119.0  5050.0   805.0   638.0   329.0   170.0     3.0     NaN
# 100  2009  4121.0  5226.0   873.0   824.0   341.0   113.0     NaN     1.0
# 101  2010  3974.0  4840.0   830.0  1030.0   357.0    78.0     NaN     NaN
# 102  2011  3829.0  5139.0   842.0  1112.0   322.0   120.0     1.0     NaN
# 103  2012  3336.0  3657.0   852.0  1055.0   383.0    63.0     NaN     1.0
# 104  2013  3794.0  4042.0   953.0   915.0   297.0    80.0     3.0     NaN
# 105  2014  3362.0  3504.0   876.0  1108.0   262.0   103.0     4.0     1.0
# 106  2015  3356.0  3674.0   989.0   688.0   312.0    61.0     2.0     NaN
# 107  2016  3386.0  2643.0   898.0   588.0   308.0    37.0     1.0     NaN
# ...

# %%
seal1_2005['haremp'] = seal1_2005['haremp'] + seal1_2005['haremg']
seal1_2005['idlep'] = seal1_2005['idlep'] + seal1_2005['idleg']
seal1_2005['mkillp'] = seal1_2005['mkillp'] + seal1_2005['mkillg']
seal1_2005['pbornp'] = seal1_2005['pbornp'] + seal1_2005['pborng']
seal1_2005['pdeadp'] = seal1_2005['pdeadp'] + seal1_2005['pdeadg']

seal1_2005 = seal1_2005.drop(['haremg', 'idleg', 'mkillg', 'fkillp', 'fkillg', 'pborng', 'pdeadg'], axis=1)

seal1_2005 = seal1_2005.rename(columns={'haremp':'males_w_mates', 'idlep':'males_wo_mates', 'mkillp':'males_killed', 'pbornp':'pups_born', 'pdeadp':'dead_pups'})
seal1_2005.reset_index(inplace=True)
seal_population = seal1_2005
seal_population
# Out:
#     index  year  males_w_mates  males_wo_mates  males_killed  pups_born  \
# 0      96  2005         4420.0          6445.0         618.0        NaN
# 1      97  2006         4389.0          6933.0         604.0   127033.0
# 2      98  2007         4312.0          5829.0         477.0        NaN
# 3      99  2008         4924.0          5688.0         499.0   120834.0
# 4     100  2009         4994.0          6050.0         454.0        NaN
# 5     101  2010         4804.0          5870.0         435.0   112475.0
# 6     102  2011         4671.0          6251.0         442.0        NaN
# 7     103  2012         4188.0          4712.0         446.0   113012.0
# 8     104  2013         4747.0          4957.0         377.0        NaN
# 9     105  2014         4238.0          4612.0         365.0   110674.0
# 10    106  2015         4345.0          4362.0         373.0        NaN
# 11    107  2016         4284.0          3231.0         345.0   101131.0
# ...

# %% [markdown]
# ## Alaskan Phocid Morphometrics, 1991 to 2015

# %%
# imports
import pandas as pd
import numpy as np
import re

# %%
# expand max output preview length
pd.set_option('display.max_rows', None)   
morpho_df = pd.read_csv('data/morphometrics_data.csv')
morpho_df.columns
# Out:
# Index(['speno', 'standardlength_cm', 'curvilinearlength_cm',
#        'standardsupinelength_cm', 'hipgirth_cm', 'maxgirth_cm',
#        'axillarygirth_cm', 'mass_kg', 'blubberthickness_cm',
#        'blubberdepthrightlateralhipa', 'blubberdepthrightlateralhipb',
#        'blubberdepthdorsalhipa_cm', 'blubberdepthdorsalhipb_cm',
#        'blubberdepthdorsalaxillarya', 'blubberdepthdorsalaxillaryb',
#        'blubberdepthlateralaxillarya', 'blubberdepthlateralaxillaryb',
#        'condition', 'morphometriccomments'],
#       dtype='object')

# %%
# read all valid comments for this dataset
# df2[df2["morphometriccomments"].notna()]["morphometriccomments"]

# drop all nan rows, ignoring speno column (which will never be NaN)
morpho_df = morpho_df.dropna(how='all', subset=morpho_df.columns.difference(['speno']))

# %%
morpho_df = morpho_df.loc[:, morpho_df.isnull().mean() < 0.8]
morpho_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 925 entries, 32 to 1752
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   speno                         925 non-null    object
#  1   standardlength_cm             639 non-null    float64
#  2   curvilinearlength_cm          613 non-null    float64
#  3   hipgirth_cm                   431 non-null    float64
#  4   maxgirth_cm                   689 non-null    float64
#  5   axillarygirth_cm              872 non-null    float64
#  6   mass_kg                       643 non-null    float64
#  7   blubberthickness_cm           233 non-null    float64
#  8   blubberdepthrightlateralhipa  189 non-null    float64
#  9   blubberdepthdorsalhipa_cm     188 non-null    float64
#  10  blubberdepthdorsalaxillarya   201 non-null    float64
#  11  blubberdepthlateralaxillarya  187 non-null    float64
# dtypes: float64(11), object(1)
# ...

# %% [markdown]
# We need the morphometrics data as a time series to spot correlations and trends with the other datasets, so lets find the years that data was recorded by extracting it from the "speno" variables.

# %%
# use regex to get all numerical components of a string
def extract_numerical_components(string):
    numerical_components = re.findall(r'\d+', string)
    numerical_components = [int(component) for component in numerical_components]
    return numerical_components

# figure out how many years we have data for
years = []
for index, row in morpho_df.iterrows():
    speno_value = row['speno']
    # only pay attention to the year component
    year = extract_numerical_components(speno_value)[0]
    years.append(year)

print(years)
unique_years = set(years)
print(unique_years)
# Out:
# [2016, 2016, 2016, 2017, 2017, 2017, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2016, 1991, 2014, 2005, 2009, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 2004, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2006, 2006, 2006, 2006, 2006, 2006, 2011, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 2005, 1991, 1991, 1991, 2005, 2005, 2005, 2005, 2009, 2009, 2011, 2005, 2005, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 2005, 2005, 2005, 1991, 1991, 1991, 2006, 2006, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 1991, 2005, 2005, 2005, 2005, 2006, 2006, 2006, 2
# ...

# %% [markdown]
# Next, we can organize it by those years and reformat it using groupby!

# %%
morpho_df['year'] = years
# drop speno col
morpho_time = morpho_df.drop(columns=['speno'])
# group by yr
morpho_time = morpho_time.groupby('year').mean().reset_index()

# %%
# drop blubber columns since they are mostly NaN
morpho_time = morpho_time.drop(columns=['blubberthickness_cm', 'blubberdepthrightlateralhipa', 'blubberdepthdorsalhipa_cm','blubberdepthdorsalaxillarya','blubberdepthlateralaxillarya'])

# %% [markdown]
# ## Ocean Economy Dataset

# %%
econ_df = pd.read_csv(r"https://docs.google.com/spreadsheets/d/e/2PACX-1vQmu_3NQO_chfAf92vo4MNsojvQlNc7ytpHUzQqo1ld_W27nQGzhd1y3aChVdIoa4SuYcW33m9Lou8U/pub?gid=1042065862&single=true&output=csv")
econ_df.head()
# Out:
#    GeoId GeoName  GeoScale StateAbbrv  OceanSect_Id          OceanSector  \
# 0     -1    West  Regional        NaN             1  Marine Construction
# 1     -1    West  Regional        NaN             1  Marine Construction
# 2     -1    West  Regional        NaN             1  Marine Construction
# 3     -1    West  Regional        NaN             1  Marine Construction
# 4     -1    West  Regional        NaN             1  Marine Construction
#
#    Year  Establishments  Employment        Wages           GDP       RealGDP
# 0  2005             543       11131  714216747.0  1.544063e+09  1.861197e+09
# 1  2006             542       11229  782883325.0  1.638811e+09  1.809474e+09
# 2  2007             536       11641  815120366.0  1.643436e+09  1.713987e+09
# 3  2008             546       10889  803254712.0  1.444904e+09  1.498542e+09
# 4  2009             542        9200  705611178.0  1.304728e+09  1.331279e+09

# %%
econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53499 entries, 0 to 53498
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GeoId           53499 non-null  int64
#  1   GeoName         53499 non-null  object
#  2   GeoScale        53499 non-null  object
#  3   StateAbbrv      52407 non-null  object
#  4   OceanSect_Id    53499 non-null  int64
#  5   OceanSector     53499 non-null  object
#  6   Year            53499 non-null  int64
#  7   Establishments  53499 non-null  int64
#  8   Employment      53499 non-null  int64
#  9   Wages           53499 non-null  float64
#  10  GDP             53499 non-null  float64
#  11  RealGDP         53499 non-null  float64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 4.9+ MB

# %% [markdown]
# ##### We are only interested in the data regarding Alaska, on a state-wide level. So we will only keep rows with `GeoName` equal to 'Alaska'. Thus, the column `StateAbbrv` is redundant since all entries will include 'Alaska' as the GeoName, so we will remove it. Also, the column `GeoId` is extraneous, so we will remove it. The dataset initially includes both `GDP` and `RealGDP`, where `RealGDP` adjusts for inflation. We will prefer to use `RealGDP` because it is better for comparisons over the years. Therefore, we will drop the column `GDP`.

# %%
econ_df = econ_df[ econ_df['GeoName'] == 'Alaska']
econ_df = econ_df[['GeoName', 'GeoScale', 'OceanSect_Id', 'OceanSector', 'Year', 'Establishments', 'Employment', 'Wages', 'RealGDP']]
econ_df = econ_df.reset_index(drop=True)
econ_df.head()
# Out:
#   GeoName GeoScale  OceanSect_Id          OceanSector  Year  Establishments  \
# 0  Alaska    State             1  Marine Construction  2005              42
# 1  Alaska    State             1  Marine Construction  2006              37
# 2  Alaska    State             1  Marine Construction  2007              37
# 3  Alaska    State             1  Marine Construction  2008              36
# 4  Alaska    State             1  Marine Construction  2009              38
#
#    Employment       Wages      RealGDP
# 0         525  45804311.0  108423563.0
# 1         679  57397023.0  121621687.0
# 2         633  55415029.0  111141686.0
# 3         641  52696469.0   98275880.0
# 4         518  49601169.0   97392558.0

# %% [markdown]
# ##### Below, we check for any null values in the dataframe.

# %%
econ_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ##### Now, we inspect each column.

# %%
print(econ_df.OceanSect_Id.value_counts().sort_index())
print(econ_df.OceanSector.value_counts().sort_index())
print(econ_df.Year.value_counts().sort_index())
print(econ_df.Establishments.describe())
print(econ_df.Employment.describe())
print(econ_df.Wages.describe())
print(econ_df.RealGDP.describe())
# Out:
# OceanSect_Id
# 1    17
# 2    17
# 3    17
# 4    17
# 5    17
# 6    17
# 9    17
# Name: count, dtype: int64
# OceanSector
# All Ocean Sectors              17
# Living Resources               17
# Marine Construction            17
# Marine Transportation          17
# Offshore Mineral Extraction    16
# Offshore Mineral Resources      1
# Ship and Boat Building         17
# Tourism and Recreation         17
# Name: count, dtype: int64
# Year
# 2005    7
# 2006    7
# 2007    7
# 2008    7
# 2009    7
# 2010    7
# 2011    7
# 2012    7
# 2013    7
# 2014    7
# 2015    7
# 2016    7
# 2017    7
# 2018    7
# 2019    7
# 2020    7
# 2021    7
# Name: count, dtype: int64
# count     119.000000
# mean      663.680672
# std       856.080781
# min        21.000000
# 25%        46.500000
# 50%       189.000000
# 75%      1565.500000
# max      2528.000000
# Name: Establishments, dtype: float64
# count      119.000000
# mean     12786.151261
# std      14937.586991
# ...

# %% [markdown]
# ##### A discrepancy is that one of the entries in the `OceanSector` column is "Offshore Mineral Resources" while the rest of the entries for that sector are named "Offshore Mineral Extraction". We will replace the single "Offshore Mineral Resources" entry with "Offshore Mineral Extraction" to maximize consistency and minimize discrepancies.

# %%
econ_df = econ_df.replace(to_replace='Offshore Mineral Resources', value='Offshore Mineral Extraction')
econ_df.OceanSector.value_counts()
# Out:
# OceanSector
# Marine Construction            17
# Living Resources               17
# Offshore Mineral Extraction    17
# Ship and Boat Building         17
# Tourism and Recreation         17
# Marine Transportation          17
# All Ocean Sectors              17
# Name: count, dtype: int64

# %% [markdown]
# ##### Now, our Ocean Economy Dataset is tidy and ready to be analyzed!

# %%
econ_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GeoName         119 non-null    object
#  1   GeoScale        119 non-null    object
#  2   OceanSect_Id    119 non-null    int64
#  3   OceanSector     119 non-null    object
#  4   Year            119 non-null    int64
#  5   Establishments  119 non-null    int64
#  6   Employment      119 non-null    int64
#  7   Wages           119 non-null    float64
#  8   RealGDP         119 non-null    float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 8.5+ KB

# %%
econ_df.head()
# Out:
#   GeoName GeoScale  OceanSect_Id          OceanSector  Year  Establishments  \
# 0  Alaska    State             1  Marine Construction  2005              42
# 1  Alaska    State             1  Marine Construction  2006              37
# 2  Alaska    State             1  Marine Construction  2007              37
# 3  Alaska    State             1  Marine Construction  2008              36
# 4  Alaska    State             1  Marine Construction  2009              38
#
#    Employment       Wages      RealGDP
# 0         525  45804311.0  108423563.0
# 1         679  57397023.0  121621687.0
# 2         633  55415029.0  111141686.0
# 3         641  52696469.0   98275880.0
# 4         518  49601169.0   97392558.0

# %%
econ_df['OceanSector'].unique()
# Out:
# array(['Marine Construction', 'Living Resources',
#        'Offshore Mineral Extraction', 'Ship and Boat Building',
#        'Tourism and Recreation', 'Marine Transportation',
#        'All Ocean Sectors'], dtype=object)

# %% [markdown]
# #### Merging
#
# We will probably merge the datasets when it comes to creating models and comparing seal health to Alaskan economic activity. To make a merged dataframe, we would merge on the year. This presents a minor problem as the Alaska economy dataset has a industry sector column with repeated years associated with each type of industry. To fix this, we would implement a method that would separate the industry sectors into separate columns and transpose the resulting columns so that each year in the year column is unique and can therefore be merged with the other dataframes.

# %%
econ_df_merge = econ_df.pivot_table(index="Year", columns="OceanSector", values=["Establishments", "Employment", "Wages", "RealGDP"]).reset_index()
econ_df_merge
# Out:
#              Year        Employment                                       \
# OceanSector       All Ocean Sectors Living Resources Marine Construction
# 0            2005           39576.0           9074.0               525.0
# 1            2006           41886.0           9749.0               679.0
# 2            2007           43438.0           9513.0               633.0
# 3            2008           44453.0           9389.0               641.0
# 4            2009           43665.0           9443.0               518.0
# 5            2010           44367.0           9608.0               560.0
# 6            2011           46548.0          10844.0               434.0
# 7            2012           47958.0          10786.0               400.0
# 8            2013           48756.0          11086.0               461.0
# 9            2014           50368.0          11228.0               486.0
# 10           2015           50742.0          10797.0               355.0
# ...

# %%
morpho_df['year'] = years

# %%
morpho_df.drop(columns=['speno'], inplace=True)
morpho_df_merge = morpho_df.groupby('year').mean().reset_index()
morpho_df_merge
# Out:
#     year  standardlength_cm  curvilinearlength_cm  hipgirth_cm  maxgirth_cm  \
# 0   1991                NaN                   NaN          NaN   151.077477
# 1   2004         136.541667            145.171429          NaN          NaN
# 2   2005         125.301282            139.557377          NaN   101.962963
# 3   2006         116.615385            125.344444          NaN          NaN
# 4   2007         127.232877            138.335616    77.250000   104.852113
# 5   2008         137.700000            149.000000    80.020000   103.240000
# 6   2009         115.300000            123.936842    66.800000    92.361111
# 7   2010         102.309524            113.235714    67.392857    92.297619
# 8   2011         173.666667            185.333333          NaN   137.500000
# 9   2012         168.500000            181.500000    93.000000   133.000000
# 10  2014         118.193182            129.488372    75.883721    99.755814
# ...

# %%
seal1_2005
# Out:
#     index  year  males_w_mates  males_wo_mates  males_killed  pups_born  \
# 0      96  2005         4420.0          6445.0         618.0        NaN
# 1      97  2006         4389.0          6933.0         604.0   127033.0
# 2      98  2007         4312.0          5829.0         477.0        NaN
# 3      99  2008         4924.0          5688.0         499.0   120834.0
# 4     100  2009         4994.0          6050.0         454.0        NaN
# 5     101  2010         4804.0          5870.0         435.0   112475.0
# 6     102  2011         4671.0          6251.0         442.0        NaN
# 7     103  2012         4188.0          4712.0         446.0   113012.0
# 8     104  2013         4747.0          4957.0         377.0        NaN
# 9     105  2014         4238.0          4612.0         365.0   110674.0
# 10    106  2015         4345.0          4362.0         373.0        NaN
# 11    107  2016         4284.0          3231.0         345.0   101131.0
# ...

# %% [markdown]
# ## Merge them together

# %%
econ_df_merge.columns = ['_'.join(col) for col in econ_df_merge.columns]
merge1 = pd.merge(seal1_2005, econ_df_merge, left_on='year', right_on='Year_')

# %%
merge2 = pd.merge(merge1, morpho_df_merge, left_on='year', right_on='year')
merge2
# Out:
#     index  year  males_w_mates  males_wo_mates  males_killed  pups_born  \
# 0      96  2005         4420.0          6445.0         618.0        NaN
# 1      97  2006         4389.0          6933.0         604.0   127033.0
# 2      98  2007         4312.0          5829.0         477.0        NaN
# 3      99  2008         4924.0          5688.0         499.0   120834.0
# 4     100  2009         4994.0          6050.0         454.0        NaN
# 5     101  2010         4804.0          5870.0         435.0   112475.0
# 6     102  2011         4671.0          6251.0         442.0        NaN
# 7     103  2012         4188.0          4712.0         446.0   113012.0
# 8     105  2014         4238.0          4612.0         365.0   110674.0
# 9     106  2015         4345.0          4362.0         373.0        NaN
# 10    107  2016         4284.0          3231.0         345.0   101131.0
# 11    108  2017            NaN             NaN         255.0        NaN
# ...

# %%
merge2 = pd.merge(merge1, morpho_df_merge, left_on='year', right_on='year')
merge2
# Out:
#     index  year  males_w_mates  males_wo_mates  males_killed  pups_born  \
# 0      96  2005         4420.0          6445.0         618.0        NaN
# 1      97  2006         4389.0          6933.0         604.0   127033.0
# 2      98  2007         4312.0          5829.0         477.0        NaN
# 3      99  2008         4924.0          5688.0         499.0   120834.0
# 4     100  2009         4994.0          6050.0         454.0        NaN
# 5     101  2010         4804.0          5870.0         435.0   112475.0
# 6     102  2011         4671.0          6251.0         442.0        NaN
# 7     103  2012         4188.0          4712.0         446.0   113012.0
# 8     105  2014         4238.0          4612.0         365.0   110674.0
# 9     106  2015         4345.0          4362.0         373.0        NaN
# 10    107  2016         4284.0          3231.0         345.0   101131.0
# 11    108  2017            NaN             NaN         255.0        NaN
# ...

# %%
# final_merge = merge2.drop(columns=['index', ('Year', '')])
final_merge = merge2.drop(columns=["index", "Year_"])
final_merge
# Out:
#     year  males_w_mates  males_wo_mates  males_killed  pups_born  dead_pups  \
# 0   2005         4420.0          6445.0         618.0        NaN        NaN
# 1   2006         4389.0          6933.0         604.0   127033.0     5706.0
# 2   2007         4312.0          5829.0         477.0        NaN        NaN
# 3   2008         4924.0          5688.0         499.0   120834.0     6488.0
# 4   2009         4994.0          6050.0         454.0        NaN        NaN
# 5   2010         4804.0          5870.0         435.0   112475.0     6243.0
# 6   2011         4671.0          6251.0         442.0        NaN        NaN
# 7   2012         4188.0          4712.0         446.0   113012.0     4121.0
# 8   2014         4238.0          4612.0         365.0   110674.0     3224.0
# 9   2015         4345.0          4362.0         373.0        NaN        NaN
# 10  2016         4284.0          3231.0         345.0   101131.0     2410.0
# ...

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis

# %% [markdown]
# ### Exploring the Seal Population Data
#
# We will conduct EDA on the seal population dataset to better understand the distributions of variables and the relationships between variables.

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(10,6)})

from scipy import stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# #### Birth Rate
#
# We use birth rate as an indicator of how well the seal population is doing overall. Approximately how many seals are born for each year in our dataset? Is there any trend or pattern?

# %%
sns.lineplot(x='year', y='pups_born', data=seal_population).set(title='Estimated Seal Pup Births from 2006-2018', xlabel='year', ylabel='pups born')
plt.show()
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Conclusion**
#
# As shown in the above plot, it is clear that there is a downward trend in the amount of seals born each year. This has potential to be concerning, as a steeply declining birth rate is an idication that the seal population is experiencing harm. We will investigate the statistical significance of this downward trend later in our project.

# %% [markdown]
# #### Empirical Count of Male Seals
#
# What is the distribution of the amount of seals counted by researchers between 2005-2018?
#
# The variables `males_w_mates` and `males_wo_mates` are empirical counts of seals by researchers, as opposed to the variable `pups_born` which is based on the counts collected by the researchers and then extrapolated to create an estimate for the total amount of pups born on the entire islands for the entire year.

# %%
sns.set(rc={'figure.figsize':(17,7)})

# %%
fig, axes = plt.subplots(1, 2)

sns.scatterplot(x='year', y='males_w_mates', data=seal_population, ax=axes[0]).set(title='Count of Male Seals with Mates from 2005-2018')
sns.scatterplot(x='year', y='males_wo_mates', data=seal_population, ax=axes[1]).set(title='Count of Male Seals without Mates from 2005-2018')
plt.show()

# %% [markdown]
# **Conclusion**
#
# The count of male seals with mates appears to be somewhat randomly scatterd. The lack of correlation in the first graph implies that the count of male seals with mates is rather nebulous; that it seems to fluctuate much, and so we are not able to make any concrete assessments because these two variables (year and count of male seals with mates) do not coincide. The count of male seals without mates appears to have a clearly downward trend, demonstrating a negative correlation, and so it is clear that the amount of males with mates is decreasing over the course of these twelve or so years. This implies potential danger with regards to mating and reproduction/population amongst the seals.

# %% [markdown]
# #### Total Alive Seals Compared to Deceased Seals
#
# Are the amount of adult male seals and seal pups that are found deceased proportional to the amount of alive adult males and pups, respectively?
#
# This can indicate to us whether there is a disproportionate amount of deceased seals, which could be a cause for alarm.
#
# We will do so using a regression model to plot the contrasting columns of data, first with on a broader level with alive Male Seals against Males that are killed. Then, we will consider alive pups against those who are deceased.

# %%
sns.set(rc={'figure.figsize':(10,6)})

# %%
seal_population['total_males'] = seal_population['males_w_mates'] + seal_population['males_wo_mates']

# %%
sns.lmplot(x='total_males', y='males_killed', data=seal_population, height=6, aspect=1.5)
plt.title('Total Alive Male Seals vs. Males killed')
plt.show()

# %%
sns.lmplot(x='pups_born', y='dead_pups', data=seal_population, height=6, aspect=1.5)
plt.title('Estimated Count of Pups Born vs. Count of Dead Pups')
plt.show()

# %% [markdown]
# **Conclusion**
#
# It stands to reason that in both regression plots, the coefficient of determination looks to be about the same, and given that the regression looks to be linear (if not excessively so) in both,by looking at the plots, it appears that as the alive population increases, the amount of deceased seals increases at a reasonably proportional rate, which should be the case. Larger population means more deaths happening, whether naturally or through external factors.

# %% [markdown]
# ## Morphometrics Dataset - EDA
# Lets first take a look at some properties of the dataset to get an idea of the distributions of some key health parameters for the phocids.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create a histogram plot using seaborn
sns.histplot(data=morpho_df, x="mass_kg", kde=True)

# Set plot title and labels
plt.title("Distribution of Mass (kg)")
plt.xlabel("Mass (kg)")
plt.ylabel("Count")

# Show the plot
plt.show()
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# It seems like the vast majority of seals and phocids in this dataset weight between 10 and 100 kg, with a skewness to the left. The upper tail of this distribution is quite long, however. This might be explained by large populations of adolescents or a difference between species of phocid that was captured in this dataset.

# %%
# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot histogram of 'standardlength_cm'
sns.histplot(data=morpho_df, x='standardlength_cm', kde=True, ax=axes[0])
axes[0].set_title('Histogram of Standard Length')

# Plot histogram of 'curvilinearlength_cm'
sns.histplot(data=morpho_df, x='curvilinearlength_cm', kde=True, ax=axes[1])
axes[1].set_title('Histogram of Curvilinear Length')

# Set common x-axis label
fig.text(0.5, 0.04, 'Length (cm)', ha='center')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# These histogram distributions give us a rough idea of the size of phocids in our dataset; they are between 60 and 220cm long. Interestingly, we see two major peaks where the majority of the population are concentrated. This could be explained by differences in sex or species of the phocids in the dataset.
#
#
# Now that we've gotten a feeling for the distributions of sizes of these animals, we can take some preliminary looks into the time series data to see how these characteristics might be changing over the years.

# %%
morpho_time

# Plotting 'mass_kg' data
sns.lineplot(data=morpho_df, x='year', y='mass_kg')
plt.title('Mass (kg) over the Years')
plt.xlabel('Year')
plt.ylabel('Mass (kg)')
plt.show()

# Plotting 'standardlength_cm' data
sns.lineplot(data=morpho_df, x='year', y='standardlength_cm')
plt.title('Standard Length (cm) over the Years')
plt.xlabel('Year')
plt.ylabel('Standard Length (cm)')
plt.show()
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# We can take some insights from these plots of the average mass and standard length as they change over the years. It seems like many larger phocids were recorded in the 1990s but those either died off or were not recorded in the more recent data collections. We see a noticeable increase in size of phocids between 2010 and 2014, which could be interesting to correlate with any environmental changes recorded in the other datasets.
#
# Overall, we see the size of phocids in Alaska following a slight decreasing trend, which would be interesting to investigate further and see if it is correlated with human activity.

# %% [markdown]
# ## Ocean Economy Dataset - EDA
#
# First off, we will want to compare the average GDP Across Ocean Sectors, to gain an idea of the overall economic market per sector over the course of years.
#
# RealGDP measures the overall value of the goods/products produced by a certain economy. Essentially, the higher the RealGDP, the more valuable and beneficial for the economy this particular avenue or sector will be. Thus, we'll be measuring the value of each sector, and their economic value/worth from 2005 to 2021.

# %%
for sector in econ_df['OceanSector'].unique():
    index = []

    for i in range(len(econ_df)):
        if econ_df['OceanSector'][i] == sector:
            index.append(i)
    sector_df = econ_df.iloc[index]    
    sns.lineplot(x='Year', y='RealGDP', data=sector_df, label = sector).set(title='Average RealGDP over time per sector', xlabel='year', ylabel='RealGDP')
    
plt.legend(bbox_to_anchor=(1.1, 1.05))
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ##### Conclusion
#
# As seen in the lineplot above, a majority of the RealGDP across the fifteen years (2005 - 2021) remains rather consistent, and lower than Offshore Mineral Extracton. Offshore Mineral Extraction entails extracting minerals, and in Alaska's case, metals (see: https://www.usgs.gov/centers/national-minerals-information-center/mineral-industry-alaska#:~:text=Alaska%20leads%20in%20zinc%20production,minerals%20mined%20in%20the%20State.), from drilling and mining sites. The necessity for drilling likely causes some form of ecological damage to the ocean environment for which these sea lions inhabit, but as of right now, we do not have enough evidence to firmly conclude this conjecture.
#
# When tracing the RealGDP of Offshore Mineral Extraction, it becomes apparent that the RealGDP peaked in 2008 and 2012, and has been steadily declining since, and as such, we can say that the overall value of  Mineral Extraction (Excavating minerals from rocks) has decreased over time, at least with respects to the benefit towards the economy. Yet it still remains as large as it did in 2008, and accounts for a majority of the value of the Ocean Economy.
#
#  This is important to note, as mineral extraction can harm sea lion health and potentially polute or damage their habitats, and though the RealGDP of these mineral extraction sites have decreased, they have not significantly plummeted, meaning seals and sea lions are still in danger of the consequences of Mineral Extraction. Particularly, we should keep an eye out for sea lion population between 2008 and 2012, because of this visualization.

# %% [markdown]
# ## Ocean Economy Dataset - EDA on Establishments / RealGDP (Regression Plot)
#
# Next up, we'll probably want to measure the establishments of each sector over time and compare and contrast them with the overall RealGDP present.
#
# The goal of this EDA is to determine whether or not there exists some sort of relationship between an increasing/decreasing number of establishments, and the RealGDP. The outcome will be able to tell us whether or not there exists some sort of relationship between an increasing amount of establishments, and the general success of branching out and the value of these properties.

# %%
sns.set(rc={'figure.figsize':(10,6)})

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 15))  
axes = axes.flatten() 

for i, sector in enumerate(econ_df['OceanSector'].unique()):
    sector_df = econ_df[econ_df['OceanSector'] == sector]
    
    sns.regplot(x='Establishments', y='RealGDP', data=sector_df, ax=axes[i])
    
    axes[i].set_title(sector)
    axes[i].set_xlabel('Number of Establishments')
    axes[i].set_ylabel('RealGDP')


plt.show()

# %% [markdown]
# #### Conclusion
#
# Based on the findings of these seven regression plots, we'll denote the most notable plots which have a visibly positive or negative coefficient of correlation. These are: Marine Construction, Ship and Boat Building, Living Resources, Marine Transportation, and by virtue of all the sectors being combined, 'All Ocean Sectors' also demonstrates a reasonably negative coefficient of correlation. In these conclusions, there contains some speculation that can not be fully backed up in this checkpoint's current form and may require other datasets and a wider-scope
#
# 1. Marine construction seems to have a strong negative correlation with RealGDP, implying that there is a relationship between the two; specifically, as the number of establishments dedicated to Marine construction increases, we can see that its RealGDP decreases at the same time. This means that the value of each construction establishment may not be particularly successful if oversaturated and continually expanding.
#
# 2. Ship and Boat Building have a positive correlation with RealGDP, which means that there is a relationship between the two. As the number of boat and ship building establishments increase, this means that the value of the boats and ships increase as well. This is indicative that the ship and boating business is in boom, and is an economic plus towards the residents of Alaska. More boats and ships means more quantities of export and transportation, but this also extends towards fishing as well. If these boats include fishing boats and ships as well, then it is likely that there is a lot of fish being captured as the ship and boat industry continues to rise, and so what will remain for sustenance amongst the Sea Lions?
#
# 3. There is a faintly visible positive correlation amongst Living Resources, which entails the oversight of fishing laws and regulations by the state, and so there must be several establishments set up to research and initiate this protection, while also ensuring safe and non-illegal fishing practices (see 'https://www.news.uscg.mil/Press-Releases/Article/3357611/preserving-alaskas-living-marine-resources/'). As this is done to regulate the fishing occurring within Alaska, this means that these Living Resources centers are fairly profitable for regulating and boosting Alaska's economy; as this will prevent over-fishing or other malpractices, from a surface level, it can be assumed that perhaps this will be beneficial for Seals, given that regulating fishing will give them more fish for their diet and nutrition.
#
# 4. As for Marine Transportation, there appears to be a slight positive correlation between Marine Transportation and RealGDP. As the amount of Marine Transportation increases, its value and worth and benefit for the economy does so as well. As previously mentioned, these are good for exports and trades, particularly as Alaska is one of the largest fishing exports in America, given that it produces and catches the most amount of fish and has a plethora of fisheries. It also accounts for any form of transportation or water-bound services required, which are what help make Alaska's economy run. Of course this would be beneficial for the economy; however, for the ocean itself, it may not be, particularly due to the oil spills, gas, pollution, and emissions that come off from the transportation, especially as these begin to increase in quantity.
#
# 5. There appears to be a negative correlation between all Ocean Sectors and RealGDP, which indicates that as we expand our grasp of the Ocean and its industry, the less value the average establishment will be of. Though we are able to see the individual correlations as per the previous six graphs, perhaps this is just indicative of the notion that at some point, an oversaturation of any field wields diminishing returns (in this case, for the Alaskan economy). If this signals that the Alaskan oceans are diminishing on returns, then the habitats surrounding the Sea Lions must also be diminishing (most directly because of less fish, but perhaps for other factors as well).

# %% [markdown]
# ## Inferential Analysis
#
# ### Correlation

# %% [markdown]
# We are interested in investigating the relationships between overall GDP for all ocean sectors, the number of establishments for all ocean sectors, seal population count, the amount of seals killed, and seal mass. We compute Pearson's R to show us the strength of the correlation between these variables.
#
# First, we plot our variables to see if we can visualize any correlation between them:

# %%
correlation_df = final_merge[['RealGDP_All Ocean Sectors', 'Establishments_All Ocean Sectors', 'males_w_mates', 'males_wo_mates', 'males_killed', 'mass_kg']]
correlation_df['total_males'] = correlation_df['males_w_mates'] + correlation_df['males_wo_mates']
correlation_df = correlation_df.drop(['males_w_mates', 'males_wo_mates'], axis=1)
correlation_df = correlation_df.dropna(how='any', axis=0)
correlation_df.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\alish\AppData\Local\Temp\ipykernel_18772\2905940509.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   correlation_df['total_males'] = correlation_df['males_w_mates'] + correlation_df['males_wo_mates']

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))  

dependent_variables = ['total_males', 'males_killed', 'mass_kg']

for i in range(len(dependent_variables)):
    sns.regplot(x='RealGDP_All Ocean Sectors', y=dependent_variables[i], data=correlation_df, ax=axes[i])
    title = 'GDP of All Ocean Sectors vs ' + dependent_variables[i]
    axes[i].set_title(title)
    axes[i].set_xlabel(dependent_variables[i])
    axes[i].set_ylabel('GDP of All Ocean Sectors')

plt.show()

fig, axes = plt.subplots(1, 3, figsize=(16, 4))  

for i in range(len(dependent_variables)):
    sns.regplot(x='Establishments_All Ocean Sectors', y=dependent_variables[i], data=correlation_df, ax=axes[i])
    title = 'Establishments of All Ocean Sectors vs ' + dependent_variables[i]
    axes[i].set_title(title)
    axes[i].set_xlabel(dependent_variables[i])
    axes[i].set_ylabel('Establishments of All Ocean Sectors')

plt.show()

# %% [markdown]
# From looking at the plots, we can see that `Establishments_All Ocean Sectors` and `total_males` have a strong negative correlation, `Establishments_All Ocean Sectors` and `males_killed` have a moderately negative correlation, `RealGDP_All Ocean Sectors` and `mass_kg` have a slight positive correlation, and the other combinations of variables have relatively neutral and weak correlations.

# %% [markdown]
# Now, we compute Pearson's R for each pairing of variables:

# %%
pearsons_r_df = pd.DataFrame()
p_value_df = pd.DataFrame()

independent_variables = ['RealGDP_All Ocean Sectors', 'Establishments_All Ocean Sectors']

for i in range(len(independent_variables)):
    correlations = []
    p_values = []
    for j in range(len(dependent_variables)):
        r, p_val = stats.pearsonr(correlation_df[independent_variables[i]], correlation_df[dependent_variables[j]])
        correlations.append(r)
        p_values.append(p_val)
    pearsons_r_df[independent_variables[i]] = correlations
    p_value_df[independent_variables[i]] = p_values

pearsons_r_df['dependent_variables'] = dependent_variables
pearsons_r_df.set_index('dependent_variables', drop=True, inplace=True)

pearsons_r_df.head(len(pearsons_r_df))
# Out:
#                      RealGDP_All Ocean Sectors  \
# dependent_variables
# total_males                           0.016845
# males_killed                         -0.233594
# mass_kg                               0.497918
#
#                      Establishments_All Ocean Sectors
# dependent_variables
# total_males                                 -0.900675
# males_killed                                -0.650694
# mass_kg                                     -0.001575

# %% [markdown]
# As we suspected, the Pearson's R correlation coefficient of `Establishments_All Ocean Sectors` and `total_males` is -0.90, indicating a very strong negative correlation; the Pearson's R correlation coefficient of `Establishments_All Ocean Sectors` and `males_killed` is -0.65, indicating a moderately strong ngeative correlation; the Pearson's R correlation coefficient of `RealGDP_All Ocean Sectors` and `mass_kg` is 0.50, indicating a moderately strong positive correlation; the Pearson's R correlation coefficient of `RealGDP_All Ocean Sectors` and `males_killed` is -0.23, indicating a somewhat negative correlation; the Pearson's R correlation coefficient of `RealGDP_All Ocean Sectors` and `total_males` is 0.02, indicating no correlation; and the Pearson's R correlation coefficient of `Establishments_All Ocean Sectors` and `mass_kg` is 0.001, indicating no correlation.

# %% [markdown]
# To test whether the correlations are significant, we compute the p-values for each Pearson's R. We will conduct our testing at the 10% significance level.

# %%
p_value_df['dependent_variables'] = dependent_variables
p_value_df.set_index('dependent_variables', drop=True, inplace=True)

p_value_df.head(len(p_value_df))
# Out:
#                      RealGDP_All Ocean Sectors  \
# dependent_variables
# total_males                           0.958560
# males_killed                          0.464962
# mass_kg                               0.099485
#
#                      Establishments_All Ocean Sectors
# dependent_variables
# total_males                                  0.000064
# males_killed                                 0.021940
# mass_kg                                      0.996124

# %% [markdown]
# **Conclusion**
#
# The pairings of variables with p-values less than 0.10 are:
# - `Establishments_All Ocean Sectors` and `total_males`
# - `Establishments_All Ocean Sectors` and `males_killed`
# - `RealGDP_All Ocean Sectors` and `mass_kg`
#
# Therefore, for these pairings of variables, we conclude that the correlations between them are statistically significant.

# %% [markdown]
# ### Downward Trend in Seal Birth Rate

# %%
sns.lineplot(x='year', y='pups_born', data=seal_population).set(title='Estimated Seal Pup Births from 2006-2018', xlabel='year', ylabel='pups born')
plt.show()
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Is the downward slope in seal births statistically significant, at the 99% confidence level?

# %% [markdown]
# To answer this question, we wil run a simple linear regression model with `year` as the dependent variable and `pups_born` as the independent variable. Our regression equation will take the form
# $$
# y = \beta_0 + \beta_1 x
# $$
# where
# - $y$ represents `pups_born`
# - $x$ represents `year`
# - $\beta_0$ is the y-intercept
# - $\beta_1$ is the slope
#
# We test
# $$
# H_0: \beta_1 = 0 \quad \text{vs} \quad H_1: \beta_1 < 0
# $$

# %%
births = seal_population['pups_born']
index_list = []
for i in range(len(seal_population)) :
    if not pd.isnull(seal_population['pups_born'][i]):
        index_list.append(i)
years = seal_population['year'][index_list]
births = births.dropna()

slope, intercept, r_value, p_value, std_err = stats.linregress(years, births)

print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r_value**2}")
print(f"P-value: {p_value}")
print(f"Standard Error: {std_err}")
# Out:
# Slope: -2326.8571428571427
# Intercept: 4793421.285714285
# R-squared: 0.9475836262398127
# P-value: 0.00021769787500477002
# Standard Error: 244.74252193032711

# %% [markdown]
# **Conclusion**
#
# Since the p-value of $\beta_1 = 0.0002 < 0.01 = \alpha$, therefore we reject $H_0$. Thus, it seems that there is a statistically significant downward trend in the birth of seals over the years 2006-2018. This indicates that there may be potential harmul factors affecting the seal population, which we will further investigate in this project.

# %% [markdown]
# ### Difference of Means of Seal Mass over the Years

# %% [markdown]
# Have the means of seal mass changed over the years?
#
# First, let's look at our data:

# %%
sns.lineplot(data=morpho_df, x='year', y='mass_kg')
plt.title('Mass (kg) over the Years')
plt.xlabel('Year')
plt.ylabel('Mass (kg)')
plt.show()
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\alish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# To answer our question, we conduct an ANOVA test at the 99% condifence level. We test
# $$
# H_0: \mu_1 = \mu_2 = ... = \mu_{15} \quad \text{vs} \quad \text{$H_1$: At least one $\mu$ is different}
# $$
# where $\mu_1, ... , \mu_{15}$ represent the mean of the mass of seals for each of the 15 years in the dataset, respectively.
#
# Below is our code to run the test:

# %%
model = smf.ols('mass_kg ~ year', data=morpho_df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq     df           F        PR(>F)
# year      1.012657e+06    1.0  518.001036  1.704195e-84
# Residual  1.253111e+06  641.0         NaN           NaN

# %% [markdown]
# __Conclusion__
#
# Since the p-value $1.7 \times 10^-84 < 0.01 = \alpha$, therefore we reject $H_0$. Thus, it seems that there is a statistically significant difference in the mean mass of seals over the years 1991, 2004-2012, and 2014-2018.

# %% [markdown]
# ### Which industrial sectors are most influential for the seal population count?

# %% [markdown]
# To answer this question, we construct a multivariate linear regression model. As an indicator for overall success of each industrial sector, we set our independent covariates as the `RealGDP` of each ocean industrial sector. As in indicator of population size, we set our dependent variable as the sum of `males_w_mates` and `males_wo_mates`, naming this variable as `total_males`. So, `total_males` is the total empirical count of male seals made by the researchers.
#
# To make inference from our model, we test
# $$
# H_0: \beta_i = 0 \quad \text{vs} \quad H_1: \beta_i \neq 0
# $$
# where $\beta_i$ represents the regression coefficient for each covariate in our model.
#
# We will test our hypotheses at the 15% significance level.

# %% [markdown]
# First, we curate a dataframe of the covariates and independent variables of interest:

# %%
regression_df = final_merge[['year', 'RealGDP_Living Resources', 'RealGDP_Marine Construction',
                             'RealGDP_Marine Transportation', 'RealGDP_Offshore Mineral Extraction', 
                             'RealGDP_Ship and Boat Building', 'RealGDP_Tourism and Recreation', 
                             'males_w_mates', 'males_wo_mates', 'males_killed', 'mass_kg']]
regression_df['total_males'] = final_merge['males_w_mates'] + final_merge['males_wo_mates']
regression_df = regression_df.drop(['males_w_mates', 'males_wo_mates'], axis=1)
regression_df.set_index('year', inplace=True)
regression_df = regression_df.dropna(how='any',axis=0)
regression_df.head(len(regression_df))
# Out:
# C:\Users\alish\AppData\Local\Temp\ipykernel_18772\1536525466.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regression_df['total_males'] = final_merge['males_w_mates'] + final_merge['males_wo_mates']
#       RealGDP_Living Resources  RealGDP_Marine Construction  \
# year
# 2005              6.951085e+08                  108423563.0
# 2006              8.404211e+08                  121621687.0
# 2007              8.853969e+08                  111141686.0
# 2008              8.164728e+08                   98275880.0
# 2009              8.880468e+08                   97392558.0
# 2010              7.754492e+08                  106634389.0
# 2011              8.633772e+08                   81032065.0
# ...

# %% [markdown]
# Now, we check our covariates for multicollinearity by checking the correlation between each covariate:

# %%
correlation_matrix = regression_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Since `RealGDP_Ship and Boat Building` is highly correlated with a couple other covariates, we drop this covariate from our model.

# %% [markdown]
# Now we run our regression model and check out the statistical summary:

# %%
X = regression_df.drop(['total_males', 'males_killed', 'mass_kg', 'RealGDP_Ship and Boat Building'], axis=1)
Y_total_males = regression_df['total_males']

model_total_males = sm.OLS(Y_total_males, X).fit()
model_total_males.summary()
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            total_males   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.995
# Method:                 Least Squares   F-statistic:                              437.5
# Date:                Wed, 12 Jun 2024   Prob (F-statistic):                    1.42e-08
# Time:                        13:54:10   Log-Likelihood:                         -92.885
# No. Observations:                  12   AIC:                                      195.8
# Df Residuals:                       7   BIC:                                      198.2
# ...

# %% [markdown]
# **Conclusion**
#
# Since the p-value of `RealGDP_Marine Construction` is $ 0.001 < \alpha = 0.15$, therefore we reject the null hypothesis for `RealGDP_Marine Construction`. For all other covariates in this model, the p-value is greater that 0.15, so we fail to reject $H_0$.
#
# Therefore, we conclude that Marine Construction has a statistically significant effect on the population count of seals.

# %% [markdown]
# ### Which industrial sectors are most influential for the amount of seals killed?

# %% [markdown]
# Similar to the above question, we construct a multivariate linear regression model with the same GDP covariates, but we use `males_killed` as our dependent variable.
#
# We test the same hypotheses at the same significance level, 15%.
# $$
# H_0: \beta_i = 0 \quad \text{vs} \quad H_1: \beta_i \neq 0
# $$
# where $\beta_i$ represents the regression coefficient for each covariate in our model.

# %%
Y_males_killed = regression_df['males_killed']

model_males_killed = sm.OLS(Y_males_killed, X).fit()
model_males_killed.summary()
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:           males_killed   R-squared (uncentered):                   0.992
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                              168.5
# Date:                Wed, 12 Jun 2024   Prob (F-statistic):                    3.90e-07
# Time:                        13:54:10   Log-Likelihood:                         -61.683
# No. Observations:                  12   AIC:                                      133.4
# Df Residuals:                       7   BIC:                                      135.8
# ...

# %% [markdown]
# **Conclusion**
#
# Since the p-value of `RealGDP_Marine Construction` is $ 0.010 < \alpha = 0.15$, therefore we reject the null hypothesis for `RealGDP_Marine Construction`. Since the p-value of `RealGDP_Tourism and Recreation` is $ 0.071 < \alpha = 0.15$, therefore we reject the null hypothesis for `RealGDP_Tourism and Recreation`. For all other covariates in this model, the p-value is greater that 0.15, so we fail to reject $H_0$.
#
# Therefore, we conclude that Marine Construction and Tourism and Recreation have statistically significant effects on the amount of seals killed.

# %% [markdown]
# ### Which industrial sectors are most influential for the mass of seals?

# %% [markdown]
# Once again, we construct a multivariate linear regression model with the same GDP covariates, but we use `mass_kg` as our dependent variable.
#
# We test the same hypotheses at the same significance level, 15%.
# $$
# H_0: \beta_i = 0 \quad \text{vs} \quad H_1: \beta_i \neq 0
# $$
# where $\beta_i$ represents the regression coefficient for each covariate in our model.

# %%
Y_mass = regression_df['mass_kg']

model_mass = sm.OLS(Y_mass, X).fit()
model_mass.summary()
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                mass_kg   R-squared (uncentered):                   0.851
# Model:                            OLS   Adj. R-squared (uncentered):              0.745
# Method:                 Least Squares   F-statistic:                              8.007
# Date:                Wed, 12 Jun 2024   Prob (F-statistic):                     0.00821
# Time:                        13:54:10   Log-Likelihood:                         -57.625
# No. Observations:                  12   AIC:                                      125.3
# Df Residuals:                       7   BIC:                                      127.7
# ...

# %% [markdown]
# **Conclusion**
#
# Since the p-value of `RealGDP_Offshore Mineral Extraction` is $ 0.122 < \alpha = 0.15$, therefore we reject the null hypothesis for `RealGDP_Offshore Mineral Extraction`. For all other covariates in this model, the p-value is greater that 0.15, so we fail to reject $H_0$.
#
# Therefore, we conclude that Offshore Mineral Extraction has a statistically significant effect on the mass of seals.

# %% [markdown]
# ## Predictive Analysis

# %% [markdown]
# For this analysis we want to fit a regression model to determine what factors contribute the most to declining seal health.

# %% [markdown]
# ### Preprocessing for Regression

# %%
from sklearn.preprocessing import StandardScaler

final_merge.columns = final_merge.columns.map(str)
final_merge.dropna(axis=1, inplace=True)
final_merge.columns = [str(col).replace("('", "").replace("', '", "_").replace("')", "").replace(" ", "_") for col in final_merge.columns]
final_merge = final_merge.drop(columns=['standardlength_cm', 'curvilinearlength_cm', 'axillarygirth_cm'])

scaler = StandardScaler()
final_merge_scaled = scaler.fit_transform(final_merge)

final_merge_scaled = pd.DataFrame(final_merge_scaled, columns=final_merge.columns)
final_merge_scaled['year'] = final_merge['year']
final_merge_scaled
# Out:
#     year  males_killed  Employment_All_Ocean_Sectors  \
# 0   2005      1.808363                     -1.922847
# 1   2006      1.673144                     -1.165858
# 2   2007      0.446519                     -0.657267
# 3   2008      0.659005                     -0.324651
# 4   2009      0.224374                     -0.582879
# 5   2010      0.040863                     -0.352833
# 6   2011      0.108472                      0.361882
# 7   2012      0.147106                      0.823940
# 8   2014     -0.635230                      1.613699
# 9   2015     -0.557962                      1.736259
# 10  2016     -0.828400                      0.694171
# 11  2017     -1.697662                     -0.054953
# 12  2018     -1.388591                     -0.168665
#
#     Employment_Living_Resources  Employment_Marine_Construction  \
# 0                     -1.416141                        0.406220
# 1                     -0.410261                        1.581442
# ...

# %% [markdown]
# # Try Linear Regression, Ridge Regression, Lasso Regression to see which best predicts seal health in mass_kg

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

X = final_merge.drop(columns=['mass_kg'])
y = final_merge['mass_kg']

# Standardize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA()
X_pca = pca.fit_transform(X_scaled)

explained_variance = np.cumsum(pca.explained_variance_ratio_)
num_components = np.argmax(explained_variance >= 0.95) + 1

# Reduce to the selected number of components
pca = PCA(n_components=num_components)
X_reduced = pca.fit_transform(X_scaled)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

regression_model = LinearRegression()
regression_model.fit(X_train, y_train)

y_pred = regression_model.predict(X_test)

# Evaluate the model
print("Linear Regression:")
print(f"R2 Score: {r2_score(y_test, y_pred)}")
print(f"MAE: {mean_absolute_error(y_test, y_pred)}")
print(f"MSE: {mean_squared_error(y_test, y_pred)}")

# Ridge Regression
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)
y_pred_ridge = ridge_model.predict(X_test)

print("Ridge Regression:")
print(f"R2 Score: {r2_score(y_test, y_pred_ridge)}")
print(f"MAE: {mean_absolute_error(y_test, y_pred_ridge)}")
print(f"MSE: {mean_squared_error(y_test, y_pred_ridge)}")

# Lasso Regression
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X_train, y_train)
y_pred_lasso = lasso_model.predict(X_test)

print("Lasso Regression:")
print(f"R2 Score: {r2_score(y_test, y_pred_lasso)}")
print(f"MAE: {mean_absolute_error(y_test, y_pred_lasso)}")
print(f"MSE: {mean_squared_error(y_test, y_pred_lasso)}")

# Cross-validation scores
ridge_cv_scores = cross_val_score(ridge_model, X_reduced, y, cv=5, scoring='r2')
lasso_cv_scores = cross_val_score(lasso_model, X_reduced, y, cv=5, scoring='r2')

print("Ridge CV R2 Scores:", ridge_cv_scores)
print("Lasso CV R2 Scores:", lasso_cv_scores)

# Identify most influential features in predicting mass_kg
components = pca.components_
feature_importance = np.abs(components).mean(axis=0)
important_features = pd.Series(feature_importance, index=X.columns).sort_values(ascending=False)

print("Most influential features in predicting mass_kg:")
print(important_features.head(10))

plt.figure(figsize=(12, 6))

# Linear Regression results
plt.subplot(1, 3, 1)
plt.scatter(y_test, y_pred, alpha=0.6, color='blue')
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--', color='red')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Linear Regression')

# Ridge Regression results
plt.subplot(1, 3, 2)
plt.scatter(y_test, y_pred_ridge, alpha=0.6, color='green')
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--', color='red')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Ridge Regression')

# Lasso Regression results
plt.subplot(1, 3, 3)
plt.scatter(y_test, y_pred_lasso, alpha=0.6, color='purple')
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--', color='red')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Lasso Regression')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\alish\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.719e+00, tolerance: 1.545e+00
#   model = cd_fast.enet_coordinate_descent(
# Linear Regression:
# R2 Score: 0.1740841315489886
# MAE: 13.564734954075666
# MSE: 265.24539293309687
# Ridge Regression:
# R2 Score: 0.8659870426945815
# MAE: 5.9195327130192865
# MSE: 43.03866879960606
# Lasso Regression:
# R2 Score: -2.794274706650023
# MAE: 24.688214361657476
# MSE: 1218.5428612105557
# Ridge CV R2 Scores: [ -3.66348164 -33.75723781  -2.71810307  -0.70076692 -17.73136932]
# Lasso CV R2 Scores: [-14.37391441 -35.18854647  -2.91094936  -0.80636297 -36.12164426]
# Most influential features in predicting mass_kg:
# RealGDP_Tourism_and_Recreation                0.251047
# ...

# %% [markdown]
# most important features at this stage:
# RealGDP_Tourism_and_Recreation                0.251047
# Establishments_Ship_and_Boat_Building         0.225469
# RealGDP_Living_Resources                      0.224384
# Establishments_Tourism_and_Recreation         0.221563
# RealGDP_Offshore_Mineral_Extraction           0.218632
# RealGDP_All_Ocean_Sectors                     0.213612
# Establishments_Offshore_Mineral_Extraction    0.188171
# Establishments_Marine_Construction            0.184740
# Employment_Offshore_Mineral_Extraction        0.160110
# Employment_Living_Resources                   0.157319
#
# # Clearly ridge regression works, but our dataset is so small (test set is literally 3 points) that it will most likely not fit well to unseen data
# # Try bootstrapping and pca to make our model more robust:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge
from sklearn.utils import resample
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

X = final_merge.drop(columns=['mass_kg'])
y = final_merge['mass_kg']

# Standardize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA
pca = PCA(n_components=0.95)
X_reduced = pca.fit_transform(X_scaled)

ridge_model = Ridge(alpha=1.0)

# Bootstrapp
n_iterations = 1000
n_size = len(X_reduced)
r2_scores = []
mae_scores = []
mse_scores = []
coefs = np.zeros((n_iterations, X.shape[1]))

for i in range(n_iterations):
    X_train, y_train = resample(X_reduced, y, n_samples=n_size, random_state=i)
    
    ridge_model.fit(X_train, y_train)
    
    y_pred_train = ridge_model.predict(X_train)
    r2_scores.append(r2_score(y_train, y_pred_train))
    mae_scores.append(mean_absolute_error(y_train, y_pred_train))
    mse_scores.append(mean_squared_error(y_train, y_pred_train))
    
    coefs[i, :len(ridge_model.coef_)] = ridge_model.coef_

# Average of metrics
mean_r2 = np.mean(r2_scores)
mean_mae = np.mean(mae_scores)
mean_mse = np.mean(mse_scores)
std_r2 = np.std(r2_scores)
std_mae = np.std(mae_scores)
std_mse = np.std(mse_scores)

print(f"Ridge Regression with Bootstrapping:")
print(f"Mean R2 Score: {mean_r2} ± {std_r2}")
print(f"Mean MAE: {mean_mae} ± {std_mae}")
print(f"Mean MSE: {mean_mse} ± {std_mse}")

# Average coefficient importance
mean_coefs = np.mean(coefs, axis=0)

# Map them back to the original features
important_features = pd.Series(mean_coefs, index=X.columns).sort_values(ascending=False)

print("Most influential features in predicting mass_kg:")
print(important_features.head(10))

plt.figure(figsize=(14, 8))

plt.subplot(2, 2, 1)
plt.hist(r2_scores, bins=30, color='blue', alpha=0.7)
plt.xlabel('R² Score')
plt.ylabel('Frequency')
plt.title('Distribution of R² Scores')

plt.subplot(2, 2, 2)
plt.hist(mae_scores, bins=30, color='green', alpha=0.7)
plt.xlabel('Mean Absolute Error')
plt.ylabel('Frequency')
plt.title('Distribution of MAE Scores')

plt.subplot(2, 2, 3)
plt.hist(mse_scores, bins=30, color='red', alpha=0.7)
plt.xlabel('Mean Squared Error')
plt.ylabel('Frequency')
plt.title('Distribution of MSE Scores')

plt.subplot(2, 2, 4)
important_features.head(4).plot(kind='barh', color='purple', alpha=0.7)
plt.xlabel('Coefficient Value')
plt.title('Top 4 Most Influential Features')

plt.tight_layout()
plt.show()
# Out:
# Ridge Regression with Bootstrapping:
# Mean R2 Score: 0.9144895409445959 ± 0.06088367379754064
# Mean MAE: 6.849991401208944 ± 3.27493198549188
# Mean MSE: 102.3866291457639 ± 79.23031262189537
# Most influential features in predicting mass_kg:
# Employment_Living_Resources          16.367882
# Employment_Marine_Transportation     16.039796
# Employment_All_Ocean_Sectors          4.366313
# year                                  0.809191
# RealGDP_Living_Resources              0.000000
# Wages_Ship_and_Boat_Building          0.000000
# Wages_Offshore_Mineral_Extraction     0.000000
# Wages_Marine_Transportation           0.000000
# Wages_Marine_Construction             0.000000
# Wages_Living_Resources                0.000000
# dtype: float64

# %% [markdown]
# #### What we can gather from these models
#
# Bootstrapping and PCA are used in conjunction to enhance the reliability and interpretability of the Ridge Regression model, especially when dealing with a small dataset like this. Here's why we employ these techniques and how to interpret the results:
#
# Bootstrapping:
# Increased Robustness: Bootstrapping involves resampling with replacement from the original dataset to create multiple bootstrap samples. Each sample is used to train a separate Ridge Regression model. By aggregating results across these models, we get a more robust estimate of model performance.
#
# Assessment of Model Stability: Bootstrapping allows us to assess the stability of the model by evaluating its performance across multiple samples. The variability in performance metrics (such as R², MAE, and MSE) provides insights into the model's stability and generalizability.
#
# PCA (Principal Component Analysis):
# Dimensionality Reduction: PCA reduces the dimensionality of the feature space while retaining most of the variance in the data. This is beneficial for small datasets as it helps in focusing on the most important features and reducing the risk of overfitting.
#
# Interpretability: PCA transforms the original features into a new set of uncorrelated variables (principal components). This can enhance the interpretability of the model by identifying the underlying patterns in the data and highlighting the most influential components.
#
# Interpretation of Results:
# Mean R² Score: 0.9144895409445958 ± 0.06088367379754072:
#
# The mean R² score indicates that approximately 91.4% of the variance in mass_kg can be explained by the model. The standard deviation (±0.0609) reflects the variability in model performance across different bootstrap samples.
# Mean MAE: 6.849991401208946 ± 3.274931985491882:
#
# The mean MAE represents the average absolute difference between the predicted and actual values of mass_kg. A lower MAE indicates better model performance in terms of prediction accuracy. The standard deviation (±3.2749) indicates the variability in prediction errors across bootstrap samples.
# Mean MSE: 102.38662914576402 ± 79.23031262189548:
#
# The mean MSE represents the average squared difference between the predicted and actual values of mass_kg. A lower MSE indicates better model performance in terms of prediction precision. The standard deviation (±79.2303) reflects the variability in prediction errors across bootstrap samples.
# Most Influential Features:
#
# The top features with nonzero importance are Employment_Living_Resources, Employment_Marine_Transportation, Employment_All_Ocean_Sectors, and year.
# Employment_Living_Resources and Employment_Marine_Transportation are the most influential features, suggesting that employment in these sectors has the highest impact on mass_kg.
# year also has nonzero importance, indicating that temporal trends captured by the 'year' variable contribute to predicting mass_kg.
#
# #### Conclusion:
# By employing bootstrapping and PCA, we've enhanced the reliability and interpretability of the Ridge Regression model. The results suggest that employment in living resources and marine transportation sectors are the most influential factors affecting mass_kg, while the 'year' variable also plays a significant role in predicting seal mass, albeit less so compared to the other parameters. These findings provide valuable insights into the relationships between features and the target variable, facilitating a better understanding of the factors driving seal mass variations over time.

# %%
# Observe general correlation between features, focus on wages and gdp aka the economic side of these ocean sectors. Do their success lead to less, unhealthy seals?

final_merge = final_merge.filter(regex='^(?!.*All_Ocean).*$')
final_merge = final_merge.filter(regex='^(?!.*Establishments).*$')
final_merge = final_merge.filter(regex='^(?!.*Employment).*$')

# Calculate the correlation matrix
correlation_matrix = final_merge.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10})
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Conclusions about the Correlation Matrix
#
# Based off the correlation matrix above, and given the previous tracking of Seal Birth over time, as well as the significance of the seal mass, across different time periods, we can come to several conclusions based on what is truly affecting the seal health.
#
# 1. The Correlation between Males Killed and Year - There appears to be a strongly negative correlation between the amount of males killed and the current year (-0.95). This demonstrates a correlation that as the years pass on, the amount of male seals being killed will decrease. Given as the amount of seals born is decreasing, perhaps we can gesture that the amount of seals being killed is not the reason for the decline in seal births. However, this correlation does give us hope that the male seals are being better conserved in some manners.
#
# 2. The correlation between Mass_KG and the RealGDP/Ship-Boat Building - The negative correlation is still fairly weak (-0.31), but the mass of a seal is somewhat negatively correlated by the increase of ship and boat building as the industry for it grows (the RealGDP), which gives way to more fishing, and thus means less sustenance for the seals to feed on.
#
# 3. The correlation between Mass_KG and the RealGDP/OffShore-Mineral-Extraction - It seems as if a majority of the ocean economy has little to no correlation with the mass (in kg) or general health of the seals in which we observe. The strongest correlation appears to be with regards to the offshore mineral extraction, with a 0.51 positive correlation, which indicates that... offshore mineral extraction is moderately correlated for the health of the seals?
#
# 4. The Correlation between the Males Killed and the Marine Construction - The strongest positive correlation for the amount of Males killed comes from the Marine construction and structures which are built around the marine environments and oceans which these seals inhabit. This correlation holds strong, particularly as the industry grows in value (RealGDP - Marine Construction) (0.88), and as it turns to be a more profitable profession (Wages - Marine Construction) (0.79).
#
# 5. The correlation between the Males Killed and the Living Resources - This one is particularly important to consider, as it regards conservation with regards to fishing laws, or perhaps even the conservation of seals and other such wildlife that roam the ocean. It seems that the correlation between wages_living_resources, and the amount of males killed is quite highly negative, at -0.89, while the correlation between Real_GDP_Living_Resources and the amount of males killed is more moderately negative, at -0.56. In either case, this is important, because both signify that as the amount of living resources happens to increase, this means that the amount of seals killed will decrease, which is a testament to conservation efforts that preserve and prevent overfishing, while also inciting laws which happen to help or protect these seals from any foul play or malpractices which could end in them injured or killed.
#
# Thus, from this discussion, we can conclude that in the present time, from around 2006 - 2018, the seals are mostly unaffected by the surrounding ocean economy, aside from Marine construction. With regards to mass_kg and seal health, it is moderately beneficial that mineral extraction helps the seal's diet, and the living resources appear to be doing a good job at preserving and taking care of seals, as per our conclusions.
#
# To emphasize, these are merely predictions about the behavior, and nothing concrete can be stated, as these are just correlations, but they do in fact slightly gesture towards these.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# With regards to terms of use, the datasets we will be using are publicly available, entailing that they are public access and are allowed to be utilized for the sake of research purposes, at the very least. We may perhaps reach out to individuals who hold domain-expertise on certain fields relating to sea lions, Alaskan Coastal Geography, and more. In those instances of requesting Datasets, we shall ensure that these datasets are kept only for our project purposes and used with the consent of the provider. We do not foresee the use of any real-world persons in data sets, or the release of any personal information. With respect to biases, the main concern is the geographical centering of our study: we initially envisioned it to be a study of Sea Lions and Seals within the region of San Diego, but we have soon pivoted it to examination of Sea Lions and Seals in Alaska, where there seems to be a more frequent density of these animals. This would mean that we have less domain knowledge of how the region and its foot-traffic works. Similarly, by relegating the study to Alaska, it is likely that our study and its implications can only be relegated to the sample population and size from Alaska, as opposed to the entirety of Sea Lions across America. We as a group are already aware of the region-specific bias that this holds, and this means that our observations and whatever conclusions we come to, as well as the datasets that we cull from, will have to be specialized or local to that region. We do not believe that our project will have any malicious consequences, as we are simply using it as a prediction model, rather than holding any tangible real-world affectation. Thus any malpractice or misuse of ethics within this project, we view as non-existent.

# %% [markdown]
# # Discusison
#
# Here are our conclusions...
#
# - There was a statistically significant decrease in the number of seal births over the course of twelve years, which harbors worry for the continued survival of the seals
# - The change between the mean mass of seals (1991, 2004-2012, 2014-2018), we determined was not due to random variation and likely due to other factors
# - One of the most influential factors with regards to being a predictor of seal health (the mass/kg) would be the employment in the Living Resources as well as the Marine Transportation
# sectors.
# - Offshore Mineral Extraction has a statistically significant effect on the mass of seals.
# - Marine Construction has a statistically significant effect on the population count of seals.
# - Marine Construction and Tourism and Recreation have statistically significant effects on the amount of seals killed.
#
#
# Currently there was a decrease in the number of seal births per year, which could be an indicator of a gradually shrinking seal population, particularly as less seals mean less possibility for population growth. We trace a fall in over 25,000 seals born, which seems quite drastic, and these seem to be affected by Marine Construction, and Tourism. However, given that there is overlap for the Marine construction with regards to the count of seals as well as how many are killed, we can reasonably state that Marine construction happens to be the most significant factor that is currently affecting the seals and their population. Thus, as the amount of marine construction across ocean space increases, the seals decrease in population. This is due to a myriad of reasons, but most pertinently, because of the water pollution (due to oil and and other pollutants) which are heavily utilized within the construction of these structures, and so the seals may succumb to this. Another reason is that these seals may be killed or casualties of the construction, with lots of metals or pieces and scraps coming into the ocean, and potentially killing these seals if they consume them.
#
# As for seal health in our current findings, the strongest indicator happens to be offshore mineral extraction, which seems to bode a positive relationship with the mass_kg of the seals. As we are taking the mass of the seals to indicate whether or not the seals are well-nourished or not, it seems that one effect of the mineral extraction is the creation of sediment is beneficial for fish, and that in general, this implies that the feeding conditions for these seals will become better with the further excavations and mineral extraction, allowing their diets and general health to maintain or improve along the way.
#
# Thus, for the future of the Alaskan seals, given that we wish to ensure that seal health is very much cared for, then tracking employment rate of Living Resources would be opportune - our regression indicates this is one of the most important factors, and by honing in on it, we could then ensure that the seals will continue to live in good health. However, given that the correlation matrix above indicates that there seems to be a low negative correlation between wages_living_resources and the mass/kg, we can then conclude that for the future, as we can use this for our predictions, there may be a stability or very low decrease in mass_kg over time for the seals, as the employment of Living Resources workers goes up. This means that while our conservation efforts remain mostly stable, there is reason to believe that our conservation efforts may not be enough, and result in a small decline of the seals' health (via mass_kg). Thus, it may be that rather than expanding conservation efforts, we must work on tightening or refining our current efforts, such that we see an uptick in the seal mass_kg.
#
#  As for the Marine transportation sectors, this is an indicator of seal health, in the ways that any form of transportation could have averse effects on the seals within the ocean, whether through pollution or overfishing, and that tracking how much traffic occurs with the Marine transportation sector, particularly as employment goes up, could actively harm the population of seals that we watch after. There is a weak negative correlation between wages_marine_transportation, and mass_kg of seals, indicating that in the future, if we continue to increase employment and production of Marine Transportation, then our seals will not be as healthy. To remedy this issue, in the future, it would be advisable to lessen the amount of transportation that occurs between Alaska and other territories. However, given that Alaska is a major territory for exports as well as cruises, we don't forsee there to be a decrease in the amount of marine transportation.
#
#
# One Potential Limitation we were faced with was the lack of direct fishing data we had to analyze from the internet. Perhaps that would have made the operation a lot more clear cut, but being able to directly graph or analyze the fish would have been helpful. However, in the wake of that, we were able to infer and make conclusions about the seals from a tourist + economic perspective, and how different factors are at play. Another restriction is that there may in fact be may other factors at play, such as what may be affecting the fish, or the temperatures of the water and its fluctuation, or even invasive species that may pose threats to the environment that the seals reside in. Finally, there is no way this will be indicative of any broader measure or market of seals - things such as RealGDP, the establishments, the Marine Construction, are unique to Alaska, and will vary across the different areas where the seals reside. The data we culled from is particular to Alaska, and thus, we are only able to predict further about the nature of the Alaskan seals, and not so much the seals at La Jolla. However, given our current limitations, we were still able to discover a lot about the seals just a little further north, and see a little into their future.
#
#
# # Team Contributions
#
# - Alisha Foster (Dataset research, Ocean Economy Dataset cleanup, Seal Birth/Death Dataset EDA, Inferential Analysis, Video Narration for Analysis)
# - Gino Angelici (Seal Birth/Death Dataset cleanup, Merging Dataset, Predictive Analysis on Merge Set, Background + Prior Work, Video Narration for EDA)
# - Matthew Pham (Abstract, Ethics + Privacy, Video Script + Narration + Filming, Ocean Economy EDA, Discussion + Conclusion Writeup )
# - Ben Garofalo (Morphometrics Cleanup + EDA + Analysis, Discussion, Video Editing)
